# %% [markdown]
# # TASK1
#
#
# #

# %% [markdown]
# ### 1st solution ----  sample output in the scrrenshot
#
# ###

# %% [markdown]
# ![1_2.png](attachment:1_2.png)
# ![1_1.PNG](attachment:1_1.PNG)

# %% [markdown]
# ### 2nd solution ----- in a single line ---comma separated
#
#
#
# ###

# %%
x= 2000
list_var = list()
while(x<=3200):
    if(x%7==0) and (x%5!=0):
            list_var.append(x)
    x+=1
print(*list_var, sep=",")
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# ####
#
#
# ### 3rd Solution ---- print in reverse order after taking name
#
# ####

# %%
first = input("Enter Your First Name :")
last =  input("Enter Your last Name  :")

print(last, first)
# Out:
# Enter Your First Name :gupta
# Enter Your last Name  :jalaj
# jalaj gupta

# %% [markdown]
# ####
#
#
# ### 4th solution----- volume of sphere
#
# ###

# %%
 radius = 12/2
 volume = (4/3)*(22/7)*radius*radius*radius
 print("volume of sphere is", volume)
# Out:
# volume of sphere is 905.142857142857

# %% [markdown]
# ###
#
#
#
# # TASK 2
#
#
#
# ###

# %% [markdown]
# ###
#
# ###  1st solution---- generate lsit from comma separated console input
#
# ###

# %%
str= input()
l1 = str.split(",")
print(l1)
# Out:
# 4,7,9,11
# ['4', '7', '9', '11']

# %% [markdown]
# ###
#
# ### 2nd solution ---- pattern
#
# ###

# %%
for i in range(0,9):
    if(i <= 4):
        for j in range(0,i+1):
            print("*", end=" ")
        print("\n")
    else:
        for j in range(i,9):
            print("*", end=" ")
        print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *

# %% [markdown]
# ###
#
# ### 3rd Solution--- reverse a word after getting input
#
# ###

# %%
str= input("Enter a String: ")
print("Reversed String:", str[-1::-1])
# Out:
# Enter a String: Python
# Reversed String: nohtyP

# %% [markdown]
# ###
#
# ###  4th solution ---- print preamble in the format
#
# ###

# %%
print("WE, THE PEOPLE OF INDIA,")
print("\thaving solemnly resolved to constitute India into a SOVEREIGN, !")
print("\t\tSOCIALIST, SECULAR, DEMOCRATIC REPUBLIC ")
print("\t\t and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN, !
# 		SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		 and to secure to all its citizens
